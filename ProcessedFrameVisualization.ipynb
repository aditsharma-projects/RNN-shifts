# %%
import pandas as pd
df = pd.read_csv("/users/facsupport/asharma/Data/Preprocessed/tmp/0.csv")

# %%
df
# Out:
#       Unnamed: 0  t_0  t_1  t_2   t_3   t_4  t_5  t_6  t_7   t_8  ...  \
# 0              0  0.0  0.0  0.0  0.00  0.00  0.0  0.0  0.0  0.00  ...
# 1              1  0.0  8.0  8.0  8.00  8.00  8.0  0.0  0.0  8.00  ...
# 2              2  0.0  8.0  8.0  8.00  8.00  8.0  0.0  0.0  8.00  ...
# 3              3  0.0  8.5  8.5  7.75  0.00  9.0  0.0  0.0  7.00  ...
# 4              4  0.0  0.0  7.5  7.75  7.75  0.0  0.0  7.5  7.75  ...
# ...          ...  ...  ...  ...   ...   ...  ...  ...  ...   ...  ...
# 2347        2347  0.0  0.0  0.0  0.00  0.00  0.0  0.0  0.0  0.00  ...
# 2348        2348  0.0  0.0  0.0  7.24  5.60  4.5  0.0  0.0  0.00  ...
# 2349        2349  0.0  0.0  0.0  0.00  0.00  0.0  0.0  0.0  0.00  ...
# 2350        2350  0.0  0.0  0.0  2.52  2.40  0.0  0.0  0.0  2.48  ...
# 2351        2351  0.0  0.0  0.0  0.00  0.00  0.0  0.0  0.0  0.00  ...
#
#       providerId  payType  dayOfWeek       Mon       Tue       Wed       Thu  \
# ...

# %%
for item in df.columns:
    print(item)
# Out:
# Unnamed: 0
# t_0
# t_1
# t_2
# t_3
# t_4
# t_5
# t_6
# t_7
# t_8
# t_9
# t_10
# t_11
# t_12
# t_13
# t_14
# t_15
# t_16
# t_17
# t_18
# t_19
# t_20
# t_21
# t_22
# t_23
# t_24
# t_25
# t_26
# t_27
# t_28
# t_29
# t_30
# t_31
# t_32
# t_33
# t_34
# t_35
# t_36
# t_37
# t_38
# t_39
# t_40
# t_41
# t_42
# t_43
# t_44
# t_45
# t_46
# t_47
# t_48
# t_49
# t_50
# t_51
# t_52
# t_53
# t_54
# t_55
# t_56
# t_57
# t_58
# t_59
# t_60
# t_61
# t_62
# t_63
# t_64
# t_65
# t_66
# t_67
# t_68
# t_69
# t_70
# t_71
# t_72
# t_73
# t_74
# t_75
# t_76
# t_77
# t_78
# t_79
# t_80
# t_81
# t_82
# t_83
# t_84
# t_85
# t_86
# t_87
# t_88
# t_89
# f_0
# f_1
# f_2
# f_3
# f_4
# f_5
# f_6
# f_7
# f_8
# f_9
# f_10
# f_11
# f_12
# f_13
# f_14
# f_15
# f_16
# f_17
# f_18
# f_19
# f_20
# f_21
# f_22
# f_23
# f_24
# f_25
# f_26
# f_27
# f_28
# f_29
# f_30
# f_31
# f_32
# f_33
# f_34
# f_35
# f_36
# f_37
# f_38
# f_39
# f_40
# f_41
# f_42
# f_43
# f_44
# f_45
# f_46
# f_47
# f_48
# f_49
# f_50
# f_51
# f_52
# ...
