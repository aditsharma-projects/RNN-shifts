# %%
# %run basic_model.py
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_dim = 30),
    tf.keras.layers.Dense(32),
    tf.keras.layers.Dense(1)
])

# %%
for i in range(100):
    print("EPOCH: "+str(i))
    train_epoch(model)
# Out:
# EPOCH: 0
# LOSS: tf.Tensor(40.13083267211914, shape=(), dtype=float64)
# LOSS: tf.Tensor(39.36677169799805, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 1
# LOSS: tf.Tensor(35.93070602416992, shape=(), dtype=float64)
# LOSS: tf.Tensor(35.62958526611328, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 2
# LOSS: tf.Tensor(32.81915283203125, shape=(), dtype=float64)
# LOSS: tf.Tensor(33.04022979736328, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 3
# LOSS: tf.Tensor(30.71225929260254, shape=(), dtype=float64)
# LOSS: tf.Tensor(31.20697021484375, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 4
# LOSS: tf.Tensor(29.320289611816406, shape=(), dtype=float64)
# LOSS: tf.Tensor(30.06482696533203, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 5
# LOSS: tf.Tensor(28.469141006469727, shape=(), dtype=float64)
# ...

# %%
testModel(test_set[1000:1010],model)
# Out:
# Prediction: tf.Tensor([[1.50302279]], shape=(1, 1), dtype=float64) True Value: [5.75]
# Prediction: tf.Tensor([[0.45599938]], shape=(1, 1), dtype=float64) True Value: [0.]
# Prediction: tf.Tensor([[4.7060464]], shape=(1, 1), dtype=float64) True Value: [6.97]
# Prediction: tf.Tensor([[9.02941891]], shape=(1, 1), dtype=float64) True Value: [6.81]
# Prediction: tf.Tensor([[6.4425716]], shape=(1, 1), dtype=float64) True Value: [7.25]
# Prediction: tf.Tensor([[4.85942715]], shape=(1, 1), dtype=float64) True Value: [0.81]
# Prediction: tf.Tensor([[0.65234297]], shape=(1, 1), dtype=float64) True Value: [0.]
# Prediction: tf.Tensor([[3.37363413]], shape=(1, 1), dtype=float64) True Value: [8.17]
# Prediction: tf.Tensor([[7.16658932]], shape=(1, 1), dtype=float64) True Value: [6.75]
# Prediction: tf.Tensor([[2.10895126]], shape=(1, 1), dtype=float64) True Value: [7.44]
# Mean Absolute Error: tf.Tensor([[2.52395516]], shape=(1, 1), dtype=float64)

# %%
#same Deep NN, adding activation functions
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, input_dim = 30, activation = 'relu'),
    tf.keras.layers.Dense(32, activation = 'relu'),
    tf.keras.layers.Dense(1)
])

for i in range(50):
    print("EPOCH: "+str(i))
    train_epoch(model)
# Out:
# EPOCH: 0
# LOSS: tf.Tensor(28.152667999267578, shape=(), dtype=float64)
# LOSS: tf.Tensor(29.531810760498047, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 1
# LOSS: tf.Tensor(28.15983772277832, shape=(), dtype=float64)
# LOSS: tf.Tensor(29.255138397216797, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 2
# LOSS: tf.Tensor(27.979185104370117, shape=(), dtype=float64)
# LOSS: tf.Tensor(28.874813079833984, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 3
# LOSS: tf.Tensor(27.770465850830078, shape=(), dtype=float64)
# LOSS: tf.Tensor(28.507427215576172, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 4
# LOSS: tf.Tensor(27.58604621887207, shape=(), dtype=float64)
# LOSS: tf.Tensor(28.195770263671875, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 5
# ...

# %%
testModel(test_set[1000:1010],model)
# Out:
# Prediction: tf.Tensor([[1.21921032]], shape=(1, 1), dtype=float64) True Value: [5.75]
# Prediction: tf.Tensor([[0.43395004]], shape=(1, 1), dtype=float64) True Value: [0.]
# Prediction: tf.Tensor([[4.40820404]], shape=(1, 1), dtype=float64) True Value: [6.97]
# Prediction: tf.Tensor([[9.30384165]], shape=(1, 1), dtype=float64) True Value: [6.81]
# Prediction: tf.Tensor([[6.5404818]], shape=(1, 1), dtype=float64) True Value: [7.25]
# Prediction: tf.Tensor([[5.35834372]], shape=(1, 1), dtype=float64) True Value: [0.81]
# Prediction: tf.Tensor([[0.53810222]], shape=(1, 1), dtype=float64) True Value: [0.]
# Prediction: tf.Tensor([[3.88180896]], shape=(1, 1), dtype=float64) True Value: [8.17]
# Prediction: tf.Tensor([[6.86387053]], shape=(1, 1), dtype=float64) True Value: [6.75]
# Prediction: tf.Tensor([[1.51246617]], shape=(1, 1), dtype=float64) True Value: [7.44]
# Mean Absolute Error: tf.Tensor([[2.61459369]], shape=(1, 1), dtype=float64)

# %%
# %run basic_model.py
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, input_dim = 30, activation = 'relu'),
    tf.keras.layers.Dense(32, activation = 'relu'),
    tf.keras.layers.Dense(1)
])

for i in range(50):
    print("EPOCH: "+str(i))
    train_epoch(model)
# Out:
# EPOCH: 0
# LOSS: tf.Tensor(43.554786682128906, shape=(), dtype=float64)
# LOSS: tf.Tensor(52.454681396484375, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 1
# LOSS: tf.Tensor(35.604347229003906, shape=(), dtype=float64)
# LOSS: tf.Tensor(44.170166015625, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 2
# LOSS: tf.Tensor(31.466697692871094, shape=(), dtype=float64)
# LOSS: tf.Tensor(38.082374572753906, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 3
# LOSS: tf.Tensor(28.97053337097168, shape=(), dtype=float64)
# LOSS: tf.Tensor(33.541465759277344, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 4
# LOSS: tf.Tensor(27.521373748779297, shape=(), dtype=float64)
# LOSS: tf.Tensor(30.651113510131836, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 5
# LOSS: tf.Tensor(26.802677154541016, shape=(), dtype=float64)
# ...

# %%
testModel(test_set[40:60],model)
# Out:
# Prediction: tf.Tensor([[7.20278144]], shape=(1, 1), dtype=float64) True Value: [1.]
# Prediction: tf.Tensor([[7.83212153]], shape=(1, 1), dtype=float64) True Value: [6.25]
# Prediction: tf.Tensor([[6.56961075]], shape=(1, 1), dtype=float64) True Value: [10.02]
# Prediction: tf.Tensor([[4.48893334]], shape=(1, 1), dtype=float64) True Value: [8.]
# Prediction: tf.Tensor([[6.05668294]], shape=(1, 1), dtype=float64) True Value: [9.33]
# Prediction: tf.Tensor([[8.50387062]], shape=(1, 1), dtype=float64) True Value: [6.52]
# Prediction: tf.Tensor([[2.49566947]], shape=(1, 1), dtype=float64) True Value: [9.5]
# Prediction: tf.Tensor([[1.33524109]], shape=(1, 1), dtype=float64) True Value: [2.]
# Prediction: tf.Tensor([[7.66995896]], shape=(1, 1), dtype=float64) True Value: [7.63]
# Prediction: tf.Tensor([[6.65665521]], shape=(1, 1), dtype=float64) True Value: [8.]
# Prediction: tf.Tensor([[12.5636187]], shape=(1, 1), dtype=float64) True Value: [15.]
# ...

# %%
# %run basic_model.py
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, input_dim = 30, activation = 'relu'),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.Dense(32, activation = 'relu'),
    tf.keras.layers.Dense(8, activation = 'relu'),
    tf.keras.layers.Dense(1)
])

for i in range(50):
    print("EPOCH: "+str(i))
    train_epoch(model)
# Out:
# EPOCH: 0
# LOSS: tf.Tensor(43.123817443847656, shape=(), dtype=float64)
# LOSS: tf.Tensor(43.031192779541016, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 1
# LOSS: tf.Tensor(33.004966735839844, shape=(), dtype=float64)
# LOSS: tf.Tensor(34.205413818359375, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 2
# LOSS: tf.Tensor(29.052303314208984, shape=(), dtype=float64)
# LOSS: tf.Tensor(29.816654205322266, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 3
# LOSS: tf.Tensor(27.461576461791992, shape=(), dtype=float64)
# LOSS: tf.Tensor(28.16350555419922, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 4
# LOSS: tf.Tensor(26.971614837646484, shape=(), dtype=float64)
# LOSS: tf.Tensor(27.568241119384766, shape=(), dtype=float64)
# NAN Count: 359 Successly trained batches: 1708
# EPOCH: 5
# ...

# %%
# %run basic_model.py

testModel(test_set[100:150],model)
# Out:
# Prediction: tf.Tensor([[4.31184012]], shape=(1, 1), dtype=float64) True Value: [3.92]
# Prediction: tf.Tensor([[6.911432]], shape=(1, 1), dtype=float64) True Value: [5.75]
# Prediction: tf.Tensor([[7.93234753]], shape=(1, 1), dtype=float64) True Value: [8.7]
# Prediction: tf.Tensor([[6.95077504]], shape=(1, 1), dtype=float64) True Value: [11.67]
# Prediction: tf.Tensor([[10.00896197]], shape=(1, 1), dtype=float64) True Value: [6.5]
# Prediction: tf.Tensor([[6.24702922]], shape=(1, 1), dtype=float64) True Value: [1.02]
# Prediction: tf.Tensor([[6.90544975]], shape=(1, 1), dtype=float64) True Value: [7.63]
# Prediction: tf.Tensor([[7.65869561]], shape=(1, 1), dtype=float64) True Value: [7.5]
# Prediction: tf.Tensor([[7.21049749]], shape=(1, 1), dtype=float64) True Value: [1.2]
# Prediction: tf.Tensor([[7.78124488]], shape=(1, 1), dtype=float64) True Value: [7.38]
# Prediction: tf.Tensor([[7.29525372]], shape=(1, 1), dtype=float64) True Value: [12.24]
# ...
